# %%
import pandas as pd
import os

# Define the path to the CSV file inside the mounted volume
# Ensure the CSV file is placed in the mounted directory (e.g., ./data on host is /home/jovyan/work/data in container)
file_path = '/home/jovyan/work/data/student.csv'

# Check if the file exists before reading
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print("✅ CSV file loaded successfully.")
    display(df.head())  # Show the first few rows of the dataframe
else:
    print("❌ File not found. Please check the path and ensure the file is mounted correctly.")
# Out:
# ✅ CSV file loaded successfully.
#    StudentID  MatriculationYear Gender     Race Date_Of_Birth  DiplomaID
# 0  202200001               2022   Male   Indian    2005-07-08        221
# 1  202200002               2022   Male  Chinese    2005-03-29        236
# 2  202200003               2022   Male  Chinese    2005-12-10        230
# 3  202200004               2022   Male  Chinese    2005-11-10        222
# 4  202200005               2022   Male  Chinese    2005-06-19        228

# %%
import pandas as pd
from pathlib import Path

# Define the relative path to the CSV file (relative to the notebook location)
relative_path = Path("data/student.csv")

# Check if the file exists before reading
if relative_path.exists():
    df = pd.read_csv(relative_path)
    print("✅ CSV file loaded successfully.")
    display(df.head())  # Show the first few rows
else:
    print(f"❌ File not found: {relative_path.resolve()}")
# Out:
# ✅ CSV file loaded successfully.
#    StudentID  MatriculationYear Gender     Race Date_Of_Birth  DiplomaID
# 0  202200001               2022   Male   Indian    2005-07-08        221
# 1  202200002               2022   Male  Chinese    2005-03-29        236
# 2  202200003               2022   Male  Chinese    2005-12-10        230
# 3  202200004               2022   Male  Chinese    2005-11-10        222
# 4  202200005               2022   Male  Chinese    2005-06-19        228

# %%
import pandas as pd
import os
from pathlib import Path

# Define the relative directory containing your CSV files
csv_dir = Path("data")

# Dictionary to hold DataFrames: key = filename (without .csv), value = DataFrame
dataframes = {}

# Loop through all files in the directory
for filename in os.listdir(csv_dir):
    if filename.endswith(".csv"):
        file_path = csv_dir / filename
        df_name = filename.replace(".csv", "")
        df = pd.read_csv(file_path)
        dataframes[df_name] = df
        print(f"✅ Loaded {filename} into dataframes['{df_name}']")

# Optional: display one of them
# display(dataframes['your_file_name_without_extension'].head())
# Display each DataFrame with its name
for name, df in dataframes.items():
    print(f"\n📄 DataFrame: '{name}' — {len(df)} rows × {len(df.columns)} columns")
    display(df.head())  # Shows only the first 5 rows of each DataFrame
# Out:
# ✅ Loaded school.csv into dataframes['school']
# ✅ Loaded student.csv into dataframes['student']
# ✅ Loaded studentgrade.csv into dataframes['studentgrade']
# ✅ Loaded module.csv into dataframes['module']
# ✅ Loaded diploma.csv into dataframes['diploma']
#
# 📄 DataFrame: 'school' — 6 rows × 3 columns
#    SchoolID School_Abbrv                             School_Name
# 0       101          SAS               School of Applied Science
# 1       102          SEG                   School of Engineering
# 2       103          SOH                   School of Hospitality
# 3       104          SOI                      School of Infocomm
# 4       105          SMC  School of Management and Communication
# 📄 DataFrame: 'student' — 3002 rows × 6 columns
#    StudentID  MatriculationYear Gender     Race Date_Of_Birth  DiplomaID
# 0  202200001               2022   Male   Indian    2005-07-08        221
# 1  202200002               2022   Male  Chinese    2005-03-29        236
# ...

# %%
dataframes['student']
# Out:
#        StudentID  MatriculationYear  Gender     Race Date_Of_Birth  DiplomaID
# 0      202200001               2022    Male   Indian    2005-07-08        221
# 1      202200002               2022    Male  Chinese    2005-03-29        236
# 2      202200003               2022    Male  Chinese    2005-12-10        230
# 3      202200004               2022    Male  Chinese    2005-11-10        222
# 4      202200005               2022    Male  Chinese    2005-06-19        228
# ...          ...                ...     ...      ...           ...        ...
# 2997   202401198               2024  Female  Chinese    2007-10-09        236
# 2998   202401199               2024    Male  Chinese    2006-09-15        205
# 2999   202401200               2024  Female    Malay    2006-07-23        205
# 3000  2025000001               2025  Female  Chinese    2007-03-23        232
# 3001  2025000002               2025    Male  Chinese    2007-03-25        233
#
# [3002 rows x 6 columns]
