# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text

# Connection parameters
DB_USER = "rpLesson15"
DB_PASSWORD = "Republic$01"
DB_HOST = "mysql"     # Docker Compose service name for MySQL
DB_PORT = 3306
DB_NAME = "rp_schema"

# Correct connection string using pymysql

connection_url = f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

engine = create_engine(connection_url, pool_pre_ping=True)
# Test connection


# Establish a connection
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM student"))
    rows = result.fetchall()
    columns = result.keys()

# Load into pandas manually
df_student = pd.DataFrame(rows, columns=columns)
display(df_student)
# Out:
#       StudentID MatriculationYear  Gender     Race Date_Of_Birth  DiplomaID
# 0     202200001              2022    Male   Indian    2005-07-08        221
# 1     202200002              2022    Male  Chinese    2005-03-29        236
# 2     202200003              2022    Male  Chinese    2005-12-10        230
# 3     202200004              2022    Male  Chinese    2005-11-10        222
# 4     202200005              2022    Male  Chinese    2005-06-19        228
# ...         ...               ...     ...      ...           ...        ...
# 2995  202401196              2024    Male  Chinese    2005-01-15        228
# 2996  202401197              2024    Male  Chinese    2007-04-08        217
# 2997  202401198              2024  Female  Chinese    2007-10-09        236
# 2998  202401199              2024    Male  Chinese    2006-09-15        205
# 2999  202401200              2024  Female    Malay    2006-07-23        205
#
# [3000 rows x 6 columns]
